# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3,3)

for tech in [0,1,2]:
    df = pd.read_csv("Opt/cost_vs_energy_tech{tech}.csv".format(tech=tech))
    axs[tech,0].plot(df["par"],df["cost"])
    axs[tech,0].plot(df["par"],df["energy"]/1000)
plt.show()
